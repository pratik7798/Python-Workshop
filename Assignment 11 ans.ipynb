# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
plt.style.use('classic')
import seaborn as sb
sb.set()

# %%
data=pd.DataFrame(pd.read_csv('iris.csv'))

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
with sb.axes_style('white'):
    sb.scatterplot(x="sepal_length",y="sepal_width",data=data,color='darkorange')

# %%
data.hist()
plt.show()

# %%
plt.plot(data["sepal_length"])
plt.plot(data["sepal_width"])
plt.plot(data["petal_length"])
plt.plot(data["petal_width"])
plt.legend(["sepal_length","sepal_width","petal_length","petal_width"],ncol=2,loc='upper left')

# %%
data=pd.DataFrame(pd.read_csv('iris.csv'))
sb.scatterplot(x=data['sepal_length'], y=data['sepal_width'],hue=data['species'])

# %%
sb.pairplot(data,size=2.5)
# Out:
# C:\Users\pratik\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
data1=pd.DataFrame(pd.read_csv('winemag.csv'))
data1.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
data1["points"].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
ax = plt.subplot(2,1, 2)
ax.hist(data1["points"], bins=20, orientation="horizontal");
plt.show()

# %%
a=pd.DataFrame(data1.groupby('country')['price'].mean())
A=pd.DataFrame(a.loc[['Switzerland','England','Germany','France','Hungary']])
A
# Out:
#                  price
# country
# Switzerland  85.285714
# England      51.681159
# Germany      42.257547
# France       41.139120
# Hungary      40.648276

# %%
A.plot.bar( rot=0)
